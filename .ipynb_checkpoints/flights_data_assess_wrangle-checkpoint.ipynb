# %% [markdown]
# ## Assess and Wrangle Flights Data

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('airline_delay_causes_jan10_mar18.csv')
df.head()
# Out:
#    year  month carrier            carrier_name airport  \
# 0  2010      1      9E  Pinnacle Airlines Inc.     ABE
# 1  2010      1      9E  Pinnacle Airlines Inc.     AEX
# 2  2010      1      9E  Pinnacle Airlines Inc.     ALB
# 3  2010      1      9E  Pinnacle Airlines Inc.     ALO
# 4  2010      1      9E  Pinnacle Airlines Inc.     ATL
#
#                                         airport_name  arr_flights  arr_del15  \
# 0  Allentown/Bethlehem/Easton, PA: Lehigh Valley ...         65.0       16.0
# 1           Alexandria, LA: Alexandria International         60.0       17.0
# 2                   Albany, NY: Albany International         81.0       34.0
# 3                    Waterloo, IA: Waterloo Regional          3.0        1.0
# 4  Atlanta, GA: Hartsfield-Jackson Atlanta Intern...       1067.0      271.0
#
#    carrier_ct  weather_ct         ...           security_ct  late_aircraft_ct  \
# 0        5.44        0.00         ...                   0.0              0.00
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120840 entries, 0 to 120839
# Data columns (total 21 columns):
# year                   120840 non-null int64
# month                  120840 non-null int64
# carrier                120840 non-null object
# carrier_name           120840 non-null object
# airport                120840 non-null object
# airport_name           120840 non-null object
# arr_flights            120704 non-null float64
# arr_del15              120679 non-null float64
# carrier_ct             120704 non-null float64
# weather_ct             120704 non-null float64
# nas_ct                 120704 non-null float64
# security_ct            120704 non-null float64
# late_aircraft_ct       120704 non-null float64
# arr_cancelled          120704 non-null float64
# arr_diverted           120704 non-null float64
# arr_delay              120704 non-null float64
# carrier_delay          120704 non-null float64
# weather_delay          120704 non-null float64
# ...

# %%
# create a day column and assign the value 1 to the entire column
df['day'] = 1
# create a date column from the year, month, and day columns
df['date'] = pd.to_datetime(df[['year', 'month', 'day']])
# drop the year, month, and day columns
df.drop(columns=['year', 'month', 'day'], inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120840 entries, 0 to 120839
# Data columns (total 20 columns):
# carrier                120840 non-null object
# carrier_name           120840 non-null object
# airport                120840 non-null object
# airport_name           120840 non-null object
# arr_flights            120704 non-null float64
# arr_del15              120679 non-null float64
# carrier_ct             120704 non-null float64
# weather_ct             120704 non-null float64
# nas_ct                 120704 non-null float64
# security_ct            120704 non-null float64
# late_aircraft_ct       120704 non-null float64
# arr_cancelled          120704 non-null float64
# arr_diverted           120704 non-null float64
# arr_delay              120704 non-null float64
# carrier_delay          120704 non-null float64
# weather_delay          120704 non-null float64
# nas_delay              120704 non-null float64
# security_delay         120704 non-null float64
# ...

# %%
# save the dataframe to an xlsx file
df.to_excel('airline_delay_jan10_mar18_master.xlsx', index=False)

# %% [markdown]
# ## References
# - Create datetime from multiple date columns: http://pandas.pydata.org/pandas-docs/stable/generated/pandas.to_datetime.html
# - Save dataframes to xlsx files: http://pandas.pydata.org/pandas-docs/version/0.22/generated/pandas.DataFrame.to_excel.html
